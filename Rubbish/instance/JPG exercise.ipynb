# %%
from skimage import io, transform, color
import numpy as np 
import os

# %% [markdown]
# jpglist = os.listdir("./pic")
# jpglist

# %%
picstr=  'pic/*.jpg'
coll = io.ImageCollection(picstr)

# %%
  for i in range(len(coll)):  
    img = coll[i]
    img_90 = transform.rotate(img, 90, resize=True)
    io.imshow(img_90)
    io.imsave('down/%d.jpg'%i, (img_90*255).astype(np.uint8))

# %%
img_90.dtype
# Out:
# dtype('float64')
