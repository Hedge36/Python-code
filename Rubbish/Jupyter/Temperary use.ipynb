# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.rand(100)
Y = np.random.rand(100)
color = np.random.randint(0, 255, size=100)
size = np.random.randint(10,500,size=100)
plt.scatter(X, Y, s=size, c=color, cmap=plt.cm.Blues)
