# %%
import thinkdsp

# %%
wave = thinkdsp.read_wave("../Wave/岑宁儿 - 追光者.wav")

# %%
spectrum = wave.make_spectrum()
spectrum.plot()

# %%
thinkdsp.play_wave('../Wave/岑宁儿 - 追光者.wav', player="kugou")

# %%
thinkdsp.SquareSignal(200).plot()
